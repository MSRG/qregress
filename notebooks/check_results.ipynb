# %%
# Import required packages
import sys
# !{sys.executable} -m pip install seaborn
from glob import glob
import os
import json
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from shutil import copy,move
from distutils.dir_util import copy_tree
from sklearn.metrics import r2_score

# %%
cmap=sns.color_palette('Paired',2)

# %%
best_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/5/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
best_ddcc['Predicted'] = [float(i.strip('[]')) for i in best_ddcc['Predicted']]
best_ddcc['Reference']= [float(i.strip('[]')) for i in best_ddcc['Reference']]
best_ddcc_train, best_ddcc_test = best_ddcc[best_ddcc['Data']=='Train'], best_ddcc[best_ddcc['Data']=='Test']

best_ddcc_trainr2, best_ddcc_testr2 = r2_score(best_ddcc_train['Reference'],best_ddcc_train['Predicted']), r2_score(best_ddcc_test['Reference'],best_ddcc_test['Predicted'])

AL3_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/3AL/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
AL3_ddcc['Predicted'] = [float(i.strip('[]')) for i in AL3_ddcc['Predicted']]
AL3_ddcc['Reference']= [float(i.strip('[]')) for i in AL3_ddcc['Reference']]
AL3_ddcc_train, AL3_ddcc_test = AL3_ddcc[AL3_ddcc['Data']=='Train'], AL3_ddcc[AL3_ddcc['Data']=='Test']

AL3_ddcc_trainr2, AL3_ddcc_testr2 = r2_score(AL3_ddcc_train['Reference'],AL3_ddcc_train['Predicted']), r2_score(AL3_ddcc_test['Reference'],AL3_ddcc_test['Predicted'])

AL5_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/5AL/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
AL5_ddcc['Predicted'] = [float(i.strip('[]')) for i in AL5_ddcc['Predicted']]
AL5_ddcc['Reference']= [float(i.strip('[]')) for i in AL5_ddcc['Reference']]
AL5_ddcc_train, AL5_ddcc_test = AL5_ddcc[AL5_ddcc['Data']=='Train'], AL5_ddcc[AL5_ddcc['Data']=='Test']
AL5_ddcc_trainr2, AL5_ddcc_testr2 = r2_score(AL5_ddcc_train['Reference'],AL5_ddcc_train['Predicted']), r2_score(AL5_ddcc_test['Reference'],AL5_ddcc_test['Predicted'])

AL7_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/7AL/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
AL7_ddcc['Predicted'] = [float(i.strip('[]')) for i in AL7_ddcc['Predicted']]
AL7_ddcc['Reference']= [float(i.strip('[]')) for i in AL7_ddcc['Reference']]
AL7_ddcc_train, AL7_ddcc_test = AL7_ddcc[AL7_ddcc['Data']=='Train'], AL7_ddcc[AL7_ddcc['Data']=='Test']

AL7_ddcc_trainr2, AL7_ddcc_testr2 = r2_score(AL7_ddcc_train['Reference'],AL7_ddcc_train['Predicted']), r2_score(AL7_ddcc_test['Reference'],AL7_ddcc_test['Predicted'])

AL9_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/9AL/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
AL9_ddcc['Predicted'] = [float(i.strip('[]')) for i in AL9_ddcc['Predicted']]
AL9_ddcc['Reference']= [float(i.strip('[]')) for i in AL9_ddcc['Reference']]
AL9_ddcc_train, AL9_ddcc_test = AL9_ddcc[AL9_ddcc['Data']=='Train'], AL9_ddcc[AL9_ddcc['Data']=='Test']

AL9_ddcc_trainr2, AL9_ddcc_testr2 = r2_score(AL9_ddcc_train['Reference'],AL9_ddcc_train['Predicted']), r2_score(AL9_ddcc_test['Reference'],AL9_ddcc_test['Predicted'])

RUD3_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/3RUD/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
RUD3_ddcc['Predicted'] = [float(i.strip('[]')) for i in RUD3_ddcc['Predicted']]
RUD3_ddcc['Reference']= [float(i.strip('[]')) for i in RUD3_ddcc['Reference']]
RUD3_ddcc_train, RUD3_ddcc_test = RUD3_ddcc[RUD3_ddcc['Data']=='Train'], RUD3_ddcc[RUD3_ddcc['Data']=='Test']

RUD3_ddcc_trainr2, RUD3_ddcc_testr2 = r2_score(RUD3_ddcc_train['Reference'],RUD3_ddcc_train['Predicted']), r2_score(RUD3_ddcc_test['Reference'],RUD3_ddcc_test['Predicted'])

RUD5_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/5RUD/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
RUD5_ddcc['Predicted'] = [float(i.strip('[]')) for i in RUD5_ddcc['Predicted']]
RUD5_ddcc['Reference']= [float(i.strip('[]')) for i in RUD5_ddcc['Reference']]
RUD5_ddcc_train, RUD5_ddcc_test = RUD5_ddcc[RUD5_ddcc['Data']=='Train'], RUD5_ddcc[RUD5_ddcc['Data']=='Test']

RUD5_ddcc_trainr2, RUD5_ddcc_testr2 = r2_score(RUD5_ddcc_train['Reference'],RUD5_ddcc_train['Predicted']), r2_score(RUD5_ddcc_test['Reference'],RUD5_ddcc_test['Predicted'])

RUD7_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/7RUD/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
RUD7_ddcc['Predicted'] = [float(i.strip('[]')) for i in RUD7_ddcc['Predicted']]
RUD7_ddcc['Reference']= [float(i.strip('[]')) for i in RUD7_ddcc['Reference']]
RUD7_ddcc_train, RUD7_ddcc_test = RUD7_ddcc[RUD7_ddcc['Data']=='Train'], RUD7_ddcc[RUD7_ddcc['Data']=='Test']

RUD7_ddcc_trainr2, RUD7_ddcc_testr2 = r2_score(RUD7_ddcc_train['Reference'],RUD7_ddcc_train['Predicted']), r2_score(RUD7_ddcc_test['Reference'],RUD7_ddcc_test['Predicted'])

RUD9_ddcc = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/qml_DDCC/RUD_AL/9RUD/A2_HWE-CNOT/A2_HWE-CNOT_predicted_values.csv'))
RUD9_ddcc['Predicted'] = [float(i.strip('[]')) for i in RUD9_ddcc['Predicted']]
RUD9_ddcc['Reference']= [float(i.strip('[]')) for i in RUD9_ddcc['Reference']]
RUD9_ddcc_train, RUD9_ddcc_test = RUD9_ddcc[RUD9_ddcc['Data']=='Train'], RUD9_ddcc[RUD9_ddcc['Data']=='Test']

RUD9_ddcc_trainr2, RUD9_ddcc_testr2 = r2_score(RUD9_ddcc_train['Reference'],RUD9_ddcc_train['Predicted']), r2_score(RUD9_ddcc_test['Reference'],RUD9_ddcc_test['Predicted'])

# Define the datasets
datasets = {
    0:{"AL=1, RUD=1": best_ddcc,
    "AL=3, RUD=1": AL3_ddcc,
    "AL=5, RUD=1": AL5_ddcc,
    "AL=7, RUD=1": AL7_ddcc,
    "AL=9, RUD=1": AL9_ddcc},    
    2:{'':None,
    "AL=1, RUD=3": RUD3_ddcc,
    "AL=1, RUD=5": RUD5_ddcc,
    "AL=1, RUD=7": RUD7_ddcc,
    "AL=1, RUD=9": RUD9_ddcc}    
}

r2sets = {
    0:{"AL=1, RUD=1": {"Train":best_ddcc_trainr2, "Test":best_ddcc_testr2},
    "AL=3, RUD=1": {"Train":AL3_ddcc_trainr2, "Test":AL3_ddcc_testr2},
    "AL=5, RUD=1": {"Train":AL5_ddcc_trainr2, "Test":AL5_ddcc_testr2},
    "AL=7, RUD=1": {"Train":AL7_ddcc_trainr2, "Test":AL7_ddcc_testr2},
    "AL=9, RUD=1": {"Train":AL9_ddcc_trainr2, "Test":AL9_ddcc_testr2}},    
    2:{'':None,
    "AL=1, RUD=3": {"Train":RUD3_ddcc_trainr2, "Test":RUD3_ddcc_testr2},
    "AL=1, RUD=5": {"Train":RUD5_ddcc_trainr2, "Test":RUD5_ddcc_testr2},
    "AL=1, RUD=7": {"Train":RUD7_ddcc_trainr2, "Test":RUD7_ddcc_testr2},
    "AL=1, RUD=9": {"Train":RUD9_ddcc_trainr2, "Test":RUD9_ddcc_testr2}}    
}







SIZE = 18

plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)  # fontsize of the figure title
# Create the figure with a 2D grid (scatter + KDE for Predicted + KDE for Reference)
fig, axes = plt.subplots(
    4, 6, 
    figsize=(40, 20), 
    gridspec_kw={'width_ratios': [4, 4, 4, 4, 4, 1], 'height_ratios': [1, 4, 1, 4]}, 
    # constrained_layout=True
    # sharey='row',  # Keep y-axis sharing, but remove sharex to control ticks manually,
    # sharex='col'
)

# Iterate through datasets and create scatter + KDE plots
for i, (title, data) in enumerate(datasets.items()):
    for idx,(k,v) in enumerate(data.items()):       
        if v is None:
            axes[title,idx].axis("off")  # Hide the subplot to make it a blank square
            axes[title+1,idx].axis("off")  # Hide the subplot to make it a blank square
        else:
            # KDE plot of "Predicted" (top row)
            sns.kdeplot(data=v, x="Predicted", hue='Data', ax=axes[title,idx], fill=True, palette=cmap,multiple='stack')
            axes[title,idx].set_xticklabels([])  # Hide labels but keep ticks
            axes[title,idx].set_xlabel("")  # Remove x-labels
            axes[title,idx].set_title(k)
            axes[title,idx].set_xlim(-0.1,0.1) 
            axes[title,idx].set_ylim(0,150)
            axes[title,idx].legend().set_visible(False)            
            axes[title,idx].set_yticks(np.arange(0,200,50))  
            axes[title,idx].set_yticklabels(np.arange(0,200,50)) 
            
            # Scatter plot in the middle row
            sns.scatterplot(data=v, x="Predicted", y="Reference", hue="Data", ax=axes[title+1,idx], alpha=0.7, edgecolor='k', palette=cmap)
            axes[title+1,idx].plot(range(-1,2),range(-1,2),'k--',alpha=0.5)
            axes[title+1,idx].set_xlabel(r'Predicted $t_{ij (\text{CCSD})}^{ab}$')
            axes[title+1,idx].set_ylim(-0.1,0.1)
            axes[title+1,idx].set_xlim(-0.1,0.1)
            axes[title+1,idx].text(0.03,-0.07,"Train R$^{2}$="+f"{r2sets[title][k]['Train']:.2f}\n"+"Test R$^{2}$="+f"{r2sets[title][k]['Test']:.2f}\n")
        
            axes[title+1,idx].tick_params(axis='x')  # Ensure x-tick labels are visible            
            axes[title+1,idx].set_xticks(np.linspace(-0.1,.1,7))  # Hide x-tick labels
            axes[title+1,idx].set_xticklabels([f'{i:.2f}' for i in np.linspace(-0.1,.1,7)], rotation=45)  # Hide x-tick labels    
            if title==0:
                if idx==0:
                    axes[title+1,idx].set_ylabel(r'Reference $t_{ij (\text{CCSD})}^{ab}$')  # Show y-label only for first column
                    axes[title+1,idx].set_yticks(np.linspace(-0.1,.1,7))  # Hide x-tick labels
                    axes[title+1,idx].set_yticklabels([f'{i:.2f}' for i in np.linspace(-0.1,.1,7)])  # Hide x-tick labels 
                    axes[title,idx].set_yticks(axes[title,idx].get_yticks())  # Hide x-tick labels
                    axes[title,idx].set_yticklabels(axes[title,idx].get_yticks())  # Hide x-tick labels   
                else:
                    axes[title,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title,idx].set_ylabel("")  # Remove x-labels
                    axes[title+1,idx].set_ylabel("")  # Show y-label only for first column
                    axes[title+1,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title+1,idx].set_xlabel("")  # Show y-label only for first column
                    axes[title+1,idx].set_xticklabels([])  # Hide labels but keep ticks                    
            elif title==2:                    
                if idx==1:
                    axes[title+1,idx].set_ylabel(r'Reference $t_{ij (\text{CCSD})}^{ab}$')  # Show y-label only for first column
                    axes[title+1,idx].set_yticks(np.linspace(-0.1,.1,7))  # Hide x-tick labels
                    axes[title+1,idx].set_yticklabels([f'{i:.2f}' for i in np.linspace(-0.1,.1,7)])  # Hide x-tick labels 
                    axes[title,idx].set_yticks(axes[title,idx].get_yticks())  # Hide x-tick labels
                    axes[title,idx].set_yticklabels(axes[title,idx].get_yticks())  # Hide x-tick labels   
                elif idx>1:
                    axes[title,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title,idx].set_ylabel("")  # Remove y-labels
                    axes[title+1,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title+1,idx].set_ylabel("")  # Show y-label only for first column
        
    # KDE plot of "Reference" on the far-right column (across all datasets)
    sns.kdeplot(data=best_ddcc, y="Reference", hue='Data', ax=axes[title+1, -1], fill=True, palette=cmap,multiple='stack')
    # axes[1, 5].set_xlabel("")  # Remove x-label
    axes[title+1,-1].set_xlim(0,150)
    # axes[title+1, -1].set_xticks(axes[title+1, -1].get_xticks())  # Hide x-tick labels
    # axes[title+1, -1].set_xticklabels(axes[title+1, -1].get_xticks())  # Hide x-tick labels
    axes[title+1,-1].set_ylim(-0.1,0.1)
    axes[title+1,-1].set_yticklabels([])  # Hide labels but keep ticks
    axes[title+1,-1].set_ylabel("")  # Remove x-labels
    axes[title+1,-1].legend().set_visible(False)

    if title+1==1:
        axes[title+1,-1].set_xticklabels([])  # Hide labels but keep ticks
        axes[title+1,-1].set_xlabel("")  # Remove x-labels
    else:
        
        axes[title+1,-1].set_xticks(np.arange(0,200,50))  
        axes[title+1,-1].set_xticklabels(np.arange(0,200,50), rotation=45)  
        
    # Remove empty top-right subplot
    axes[title, -1].axis("off")


plt.suptitle('5 Qubit DDCC A2_HWE-CNOT',y=0.92)
# Adjust layout
plt.subplots_adjust(wspace=0.05, hspace=0.3)  # Adjust width and height spacing

# plt.tight_layout()
plt.savefig(os.path.join(os.path.expanduser('~'),'qregress/images/DDCC/distribution_parity.png'),dpi=300,bbox_inches='tight')
plt.show()
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:180: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title+1,-1].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:129: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/1370420751.py:180: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title+1,-1].legend().set_visible(False)

# %%
best_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE-calc-test/16qubit/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
best_bse16['Predicted'] = [float(i.strip('[]')) for i in best_bse16['Predicted']]
best_bse16['Reference']= [float(i.strip('[]')) for i in best_bse16['Reference']]
best_bse16_train, best_bse16_test = best_bse16[best_bse16['Data']=='Train'], best_bse16[best_bse16['Data']=='Test']

best_bse16_trainr2, best_bse16_testr2 = r2_score(best_bse16_train['Reference'],best_bse16_train['Predicted']), r2_score(best_bse16_test['Reference'],best_bse16_test['Predicted'])

AL3_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/3AL/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
AL3_bse16['Predicted'] = [float(i.strip('[]')) for i in AL3_bse16['Predicted']]
AL3_bse16['Reference']= [float(i.strip('[]')) for i in AL3_bse16['Reference']]
AL3_bse16_train, AL3_bse16_test = AL3_bse16[AL3_bse16['Data']=='Train'], AL3_bse16[AL3_bse16['Data']=='Test']

AL3_bse16_trainr2, AL3_bse16_testr2 = r2_score(AL3_bse16_train['Reference'],AL3_bse16_train['Predicted']), r2_score(AL3_bse16_test['Reference'],AL3_bse16_test['Predicted'])

AL5_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/5AL/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
AL5_bse16['Predicted'] = [float(i.strip('[]')) for i in AL5_bse16['Predicted']]
AL5_bse16['Reference']= [float(i.strip('[]')) for i in AL5_bse16['Reference']]
AL5_bse16_train, AL5_bse16_test = AL5_bse16[AL5_bse16['Data']=='Train'], AL5_bse16[AL5_bse16['Data']=='Test']

AL5_bse16_trainr2, AL5_bse16_testr2 = r2_score(AL5_bse16_train['Reference'],AL5_bse16_train['Predicted']), r2_score(AL5_bse16_test['Reference'],AL5_bse16_test['Predicted'])

RUD3_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/3RUD/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
RUD3_bse16['Predicted'] = [float(i.strip('[]')) for i in RUD3_bse16['Predicted']]
RUD3_bse16['Reference']= [float(i.strip('[]')) for i in RUD3_bse16['Reference']]
RUD3_bse16_train, RUD3_bse16_test = RUD3_bse16[RUD3_bse16['Data']=='Train'], RUD3_bse16[RUD3_bse16['Data']=='Test']

RUD3_bse16_trainr2, RUD3_bse16_testr2 = r2_score(RUD3_bse16_train['Reference'],RUD3_bse16_train['Predicted']), r2_score(RUD3_bse16_test['Reference'],RUD3_bse16_test['Predicted'])

RUD5_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/5RUD/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
RUD5_bse16['Predicted'] = [float(i.strip('[]')) for i in RUD5_bse16['Predicted']]
RUD5_bse16['Reference']= [float(i.strip('[]')) for i in RUD5_bse16['Reference']]
RUD5_bse16_train, RUD5_bse16_test = RUD5_bse16[RUD5_bse16['Data']=='Train'], RUD5_bse16[RUD5_bse16['Data']=='Test']

RUD5_bse16_trainr2, RUD5_bse16_testr2 = r2_score(RUD5_bse16_train['Reference'],RUD5_bse16_train['Predicted']), r2_score(RUD5_bse16_test['Reference'],RUD5_bse16_test['Predicted'])


# Define the datasets
datasets = {
    0:{"AL=1, RUD=1": best_bse16,
    "AL=3, RUD=1": AL3_bse16,
    "AL=5, RUD=1": AL5_bse16},
    2:{'':None,
    "AL=1, RUD=3": RUD3_bse16,
    "AL=1, RUD=5": RUD5_bse16}
}

r2sets = {
    0:{"AL=1, RUD=1": {"Train":best_bse16_trainr2, "Test":best_bse16_testr2},
    "AL=3, RUD=1": {"Train":AL3_bse16_trainr2, "Test":AL3_bse16_testr2},
    "AL=5, RUD=1": {"Train":AL5_bse16_trainr2, "Test":AL5_bse16_testr2}},
    2:{'':None,
    "AL=1, RUD=3": {"Train":RUD3_bse16_trainr2, "Test":RUD3_bse16_testr2},
    "AL=1, RUD=5": {"Train":RUD5_bse16_trainr2, "Test":RUD5_bse16_testr2}}
}







SIZE = 18

plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)  # fontsize of the figure title
# Create the figure with a 2D grid (scatter + KDE for Predicted + KDE for Reference)
fig, axes = plt.subplots(
    4, 4, 
    figsize=(30, 20),
    gridspec_kw={'width_ratios': [4, 4, 4, 1], 'height_ratios': [1, 4, 1, 4]}, 
    # constrained_layout=True
    # sharey='row',  # Keep y-axis sharing, but remove sharex to control ticks manually,
    # sharex='col'
)
maxkde = 0.3
# Iterate through datasets and create scatter + KDE plots
for i, (title, data) in enumerate(datasets.items()):
    for idx,(k,v) in enumerate(data.items()):       
        if v is None:
            axes[title,idx].axis("off")  # Hide the subplot to make it a blank square
            axes[title+1,idx].axis("off")  # Hide the subplot to make it a blank square
        else:
            # KDE plot of "Predicted" (top row)
            sns.kdeplot(data=v, x="Predicted", hue='Data', ax=axes[title,idx], fill=True, palette=cmap,multiple='stack')
            axes[title,idx].set_xticklabels([])  # Hide labels but keep ticks
            axes[title,idx].set_xlabel("")  # Remove x-labels
            axes[title,idx].set_title(k)
            axes[title,idx].set_xlim(0,200) 
            axes[title,idx].set_ylim(0,maxkde)
            axes[title,idx].legend().set_visible(False)            
            axes[title,idx].set_yticks(np.linspace(0,maxkde,3))  
            axes[title,idx].set_yticklabels(np.linspace(0,maxkde,3)) 
            
            # Scatter plot in the middle row
            sns.scatterplot(data=v, x="Predicted", y="Reference", hue="Data", ax=axes[title+1,idx], alpha=0.7, edgecolor='k', palette=cmap)
            axes[title+1,idx].plot(range(-1,2),range(-1,2),'k--',alpha=0.5)
            axes[title+1,idx].set_xlabel(r'Predicted BSE (kcal/mol)')
            axes[title+1,idx].set_ylim(0,200)
            axes[title+1,idx].set_xlim(0,200)
            axes[title+1,idx].text(125,15,"Train R$^{2}$="+f"{r2sets[title][k]['Train']:.2f}\n"+"Test R$^{2}$="+f"{r2sets[title][k]['Test']:.2f}\n")
        
            axes[title+1,idx].tick_params(axis='x')  # Ensure x-tick labels are visible            
            axes[title+1,idx].set_xticks(np.linspace(0,200,5))  # Hide x-tick labels
            axes[title+1,idx].set_xticklabels([f'{int(i):d}' for i in np.linspace(0,200,5)], rotation=0)  # Hide x-tick labels    
            if title==0:
                if idx==0:
                    axes[title+1,idx].set_ylabel(r'Reference BSE (kcal/mol)')  # Show y-label only for first column
                    axes[title+1,idx].set_yticks(np.linspace(0,200,5))  # Hide x-tick labels
                    axes[title+1,idx].set_yticklabels([f'{int(i):d}' for i in np.linspace(0,200,5)], rotation=0)  # Hide x-tick labels    
                    axes[title,idx].set_yticks(axes[title,idx].get_yticks())  # Hide x-tick labels
                    axes[title,idx].set_yticklabels(axes[title,idx].get_yticks())  # Hide x-tick labels   
                else:
                    axes[title,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title,idx].set_ylabel("")  # Remove x-labels
                    axes[title+1,idx].set_ylabel("")  # Show y-label only for first column
                    axes[title+1,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title+1,idx].set_xlabel("")  # Show y-label only for first column
                    axes[title+1,idx].set_xticklabels([])  # Hide labels but keep ticks                    
            elif title==2:                    
                if idx==1:
                    axes[title+1,idx].set_ylabel(r'Reference BSE (kcal/mol)')  # Show y-label only for first column
                    axes[title+1,idx].set_yticks(np.linspace(0,200,5))  # Hide x-tick labels
                    axes[title+1,idx].set_yticklabels([f'{int(i):d}' for i in np.linspace(0,200,5)])  # Hide x-tick labels 
                    axes[title,idx].set_yticks(axes[title,idx].get_yticks())  # Hide x-tick labels
                    axes[title,idx].set_yticklabels(axes[title,idx].get_yticks())  # Hide x-tick labels   
                elif idx>1:
                    axes[title,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title,idx].set_ylabel("")  # Remove y-labels
                    axes[title+1,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title+1,idx].set_ylabel("")  # Show y-label only for first column
        
    # KDE plot of "Reference" on the far-right column (across all datasets)
    sns.kdeplot(data=best_bse16, y="Reference", hue='Data', ax=axes[title+1, -1], fill=True, palette=cmap,multiple='stack')
    axes[title+1,-1].set_xlim(0,maxkde)
    axes[title+1, -1].set_xticks(axes[title+1, -1].get_xticks())  # Hide x-tick labels
    axes[title+1, -1].set_xticklabels(axes[title+1, -1].get_xticks())  # Hide x-tick labels
    axes[title+1,-1].set_ylim(0,200)
    axes[title+1,-1].set_yticklabels([])  # Hide labels but keep ticks
    axes[title+1,-1].set_ylabel("")  # Remove x-labels
    axes[title+1,-1].legend().set_visible(False)

    if title+1==1:
        axes[title+1,-1].set_xticklabels([])  # Hide labels but keep ticks
        axes[title+1,-1].set_xlabel("")  # Remove x-labels
    else:
        
        axes[title+1,-1].set_xticks(np.linspace(0,maxkde,3))  
        axes[title+1,-1].set_xticklabels(np.linspace(0,maxkde,3), rotation=45)  
        
    # Remove empty top-right subplot
    axes[title, -1].axis("off")


plt.suptitle('16 Qubit BSE49 A2_Hadamard',y=0.92)
plt.subplots_adjust(wspace=0.1, hspace=0.15)  # Adjust width and height spacing
# Adjust layout
# plt.tight_layout()
plt.savefig(os.path.join(os.path.expanduser('~'),'qregress/images/BSE/sixteenqubit/distribution_parity.png'),dpi=300,bbox_inches='tight')
plt.show()
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:145: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title+1,-1].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/703273103.py:145: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title+1,-1].legend().set_visible(False)

# %%
best_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE-calc-test/5qubit/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
best_bse5['Predicted'] = [float(i.strip('[]')) for i in best_bse5['Predicted']]
best_bse5['Reference']= [float(i.strip('[]')) for i in best_bse5['Reference']]
best_bse5_train, best_bse5_test = best_bse5[best_bse5['Data']=='Train'], best_bse5[best_bse5['Data']=='Test']

best_bse5_trainr2, best_bse5_testr2 = r2_score(best_bse5_train['Reference'],best_bse5_train['Predicted']), r2_score(best_bse5_test['Reference'],best_bse5_test['Predicted'])

AL3_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/3AL/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
AL3_bse5['Predicted'] = [float(i.strip('[]')) for i in AL3_bse5['Predicted']]
AL3_bse5['Reference']= [float(i.strip('[]')) for i in AL3_bse5['Reference']]
AL3_bse5_train, AL3_bse5_test = AL3_bse5[AL3_bse5['Data']=='Train'], AL3_bse5[AL3_bse5['Data']=='Test']

AL3_bse5_trainr2, AL3_bse5_testr2 = r2_score(AL3_bse5_train['Reference'],AL3_bse5_train['Predicted']), r2_score(AL3_bse5_test['Reference'],AL3_bse5_test['Predicted'])

AL5_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/5AL/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
AL5_bse5['Predicted'] = [float(i.strip('[]')) for i in AL5_bse5['Predicted']]
AL5_bse5['Reference']= [float(i.strip('[]')) for i in AL5_bse5['Reference']]
AL5_bse5_train, AL5_bse5_test = AL5_bse5[AL5_bse5['Data']=='Train'], AL5_bse5[AL5_bse5['Data']=='Test']

AL5_bse5_trainr2, AL5_bse5_testr2 = r2_score(AL5_bse5_train['Reference'],AL5_bse5_train['Predicted']), r2_score(AL5_bse5_test['Reference'],AL5_bse5_test['Predicted'])

RUD3_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/3RUD/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
RUD3_bse5['Predicted'] = [float(i.strip('[]')) for i in RUD3_bse5['Predicted']]
RUD3_bse5['Reference']= [float(i.strip('[]')) for i in RUD3_bse5['Reference']]
RUD3_bse5_train, RUD3_bse5_test = RUD3_bse5[RUD3_bse5['Data']=='Train'], RUD3_bse5[RUD3_bse5['Data']=='Test']

RUD3_bse5_trainr2, RUD3_bse5_testr2 = r2_score(RUD3_bse5_train['Reference'],RUD3_bse5_train['Predicted']), r2_score(RUD3_bse5_test['Reference'],RUD3_bse5_test['Predicted'])

RUD5_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/5RUD/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
RUD5_bse5['Predicted'] = [float(i.strip('[]')) for i in RUD5_bse5['Predicted']]
RUD5_bse5['Reference']= [float(i.strip('[]')) for i in RUD5_bse5['Reference']]
RUD5_bse5_train, RUD5_bse5_test = RUD5_bse5[RUD5_bse5['Data']=='Train'], RUD5_bse5[RUD5_bse5['Data']=='Test']

RUD5_bse5_trainr2, RUD5_bse5_testr2 = r2_score(RUD5_bse5_train['Reference'],RUD5_bse5_train['Predicted']), r2_score(RUD5_bse5_test['Reference'],RUD5_bse5_test['Predicted'])


# Define the datasets
datasets = {
    0:{"AL=1, RUD=1": best_bse5,
    "AL=3, RUD=1": AL3_bse5,
    "AL=5, RUD=1": AL5_bse5},
    2:{'':None,
    "AL=1, RUD=3": RUD3_bse5,
    "AL=1, RUD=5": RUD5_bse5}
}

r2sets = {
    0:{"AL=1, RUD=1": {"Train":best_bse5_trainr2, "Test":best_bse5_testr2},
    "AL=3, RUD=1": {"Train":AL3_bse5_trainr2, "Test":AL3_bse5_testr2},
    "AL=5, RUD=1": {"Train":AL5_bse5_trainr2, "Test":AL5_bse5_testr2}},
    2:{'':None,
    "AL=1, RUD=3": {"Train":RUD3_bse5_trainr2, "Test":RUD3_bse5_testr2},
    "AL=1, RUD=5": {"Train":RUD5_bse5_trainr2, "Test":RUD5_bse5_testr2}}
}







SIZE = 18

plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)  # fontsize of the figure title
# Create the figure with a 2D grid (scatter + KDE for Predicted + KDE for Reference)
fig, axes = plt.subplots(
    4, 4, 
    figsize=(30, 20),
    gridspec_kw={'width_ratios': [4, 4, 4, 1], 'height_ratios': [1, 4, 1, 4]}, 
    # constrained_layout=True
    # sharey='row',  # Keep y-axis sharing, but remove sharex to control ticks manually,
    # sharex='col'
)
maxkde = 0.1
# Iterate through datasets and create scatter + KDE plots
for i, (title, data) in enumerate(datasets.items()):
    for idx,(k,v) in enumerate(data.items()):       
        if v is None:
            axes[title,idx].axis("off")  # Hide the subplot to make it a blank square
            axes[title+1,idx].axis("off")  # Hide the subplot to make it a blank square
        else:
            # KDE plot of "Predicted" (top row)
            sns.kdeplot(data=v, x="Predicted", hue='Data', ax=axes[title,idx], fill=True, palette=cmap,multiple='stack')
            axes[title,idx].set_xticklabels([])  # Hide labels but keep ticks
            axes[title,idx].set_xlabel("")  # Remove x-labels
            axes[title,idx].set_title(k)
            axes[title,idx].set_xlim(0,200) 
            axes[title,idx].set_ylim(0,maxkde)
            axes[title,idx].legend().set_visible(False)            
            axes[title,idx].set_yticks(np.linspace(0,maxkde,3))  
            axes[title,idx].set_yticklabels(np.linspace(0,maxkde,3)) 
            
            # Scatter plot in the middle row
            sns.scatterplot(data=v, x="Predicted", y="Reference", hue="Data", ax=axes[title+1,idx], alpha=0.7, edgecolor='k', palette=cmap)
            axes[title+1,idx].plot(range(-1,2),range(-1,2),'k--',alpha=0.5)
            axes[title+1,idx].set_xlabel(r'Predicted BSE (kcal/mol)')
            axes[title+1,idx].set_ylim(0,200)
            axes[title+1,idx].set_xlim(0,200)
            axes[title+1,idx].text(125,15,"Train R$^{2}$="+f"{r2sets[title][k]['Train']:.2f}\n"+"Test R$^{2}$="+f"{r2sets[title][k]['Test']:.2f}\n")
        
            axes[title+1,idx].tick_params(axis='x')  # Ensure x-tick labels are visible            
            axes[title+1,idx].set_xticks(np.linspace(0,200,5))  # Hide x-tick labels
            axes[title+1,idx].set_xticklabels([f'{int(i):d}' for i in np.linspace(0,200,5)], rotation=0)  # Hide x-tick labels    
            if title==0:
                if idx==0:
                    axes[title+1,idx].set_ylabel(r'Reference BSE (kcal/mol)')  # Show y-label only for first column
                    axes[title+1,idx].set_yticks(np.linspace(0,200,5))  # Hide x-tick labels
                    axes[title+1,idx].set_yticklabels([f'{int(i):d}' for i in np.linspace(0,200,5)], rotation=0)  # Hide x-tick labels    
                    axes[title,idx].set_yticks(axes[title,idx].get_yticks())  # Hide x-tick labels
                    axes[title,idx].set_yticklabels(axes[title,idx].get_yticks())  # Hide x-tick labels   
                else:
                    axes[title,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title,idx].set_ylabel("")  # Remove x-labels
                    axes[title+1,idx].set_ylabel("")  # Show y-label only for first column
                    axes[title+1,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title+1,idx].set_xlabel("")  # Show y-label only for first column
                    axes[title+1,idx].set_xticklabels([])  # Hide labels but keep ticks                    
            elif title==2:                    
                if idx==1:
                    axes[title+1,idx].set_ylabel(r'Reference BSE (kcal/mol)')  # Show y-label only for first column
                    axes[title+1,idx].set_yticks(np.linspace(0,200,5))  # Hide x-tick labels
                    axes[title+1,idx].set_yticklabels([f'{int(i):d}' for i in np.linspace(0,200,5)])  # Hide x-tick labels 
                    axes[title,idx].set_yticks(axes[title,idx].get_yticks())  # Hide x-tick labels
                    axes[title,idx].set_yticklabels(axes[title,idx].get_yticks())  # Hide x-tick labels   
                elif idx>1:
                    axes[title,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title,idx].set_ylabel("")  # Remove y-labels
                    axes[title+1,idx].set_yticklabels([])  # Hide labels but keep ticks
                    axes[title+1,idx].set_ylabel("")  # Show y-label only for first column
        
    # KDE plot of "Reference" on the far-right column (across all datasets)
    sns.kdeplot(data=best_bse5, y="Reference", hue='Data', ax=axes[title+1, -1], fill=True, palette=cmap,multiple='stack')
    axes[title+1,-1].set_xlim(0,maxkde)
    axes[title+1, -1].set_xticks(axes[title+1, -1].get_xticks())  # Hide x-tick labels
    axes[title+1, -1].set_xticklabels(axes[title+1, -1].get_xticks())  # Hide x-tick labels
    axes[title+1,-1].set_ylim(0,200)
    axes[title+1,-1].set_yticklabels([])  # Hide labels but keep ticks
    axes[title+1,-1].set_ylabel("")  # Remove x-labels
    axes[title+1,-1].legend().set_visible(False)

    if title+1==1:
        axes[title+1,-1].set_xticklabels([])  # Hide labels but keep ticks
        axes[title+1,-1].set_xlabel("")  # Remove x-labels
    else:
        
        axes[title+1,-1].set_xticks(np.linspace(0,maxkde,3))  
        axes[title+1,-1].set_xticklabels(np.linspace(0,maxkde,3), rotation=45)  
        
    # Remove empty top-right subplot
    axes[title, -1].axis("off")


plt.suptitle('5 Qubit BSE49 M-M-CZ_HWE-CNOT',y=0.92)
plt.subplots_adjust(wspace=0.1, hspace=0.15)  # Adjust width and height spacing
# Adjust layout
# plt.tight_layout()
plt.savefig(os.path.join(os.path.expanduser('~'),'qregress/images/BSE/fivequbit/distribution_parity.png'),dpi=300,bbox_inches='tight')
plt.show()
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:145: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title+1,-1].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title,idx].legend().set_visible(False)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/2678589938.py:145: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[title+1,-1].legend().set_visible(False)

# %%
# best_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE-calc-test/16qubit/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
# best_bse16['Predicted'] = [float(i.strip('[]')) for i in best_bse16['Predicted']]
# best_bse16['Reference']= [float(i.strip('[]')) for i in best_bse16['Reference']]
# best_bse16_train, best_bse16_test = best_bse16[best_bse16['Data']=='Train'], best_bse16[best_bse16['Data']=='Test']

# AL3_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/3AL/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
# AL3_bse16['Predicted'] = [float(i.strip('[]')) for i in AL3_bse16['Predicted']]
# AL3_bse16['Reference']= [float(i.strip('[]')) for i in AL3_bse16['Reference']]
# AL3_bse16_train, AL3_bse16_test = AL3_bse16[AL3_bse16['Data']=='Train'], AL3_bse16[AL3_bse16['Data']=='Test']

# AL5_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/5AL/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
# AL5_bse16['Predicted'] = [float(i.strip('[]')) for i in AL5_bse16['Predicted']]
# AL5_bse16['Reference']= [float(i.strip('[]')) for i in AL5_bse16['Reference']]
# AL5_bse16_train, AL5_bse16_test = AL5_bse16[AL5_bse16['Data']=='Train'], AL5_bse16[AL5_bse16['Data']=='Test']

# RUD3_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/3RUD/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
# RUD3_bse16['Predicted'] = [float(i.strip('[]')) for i in RUD3_bse16['Predicted']]
# RUD3_bse16['Reference']= [float(i.strip('[]')) for i in RUD3_bse16['Reference']]
# RUD3_bse16_train, RUD3_bse16_test = RUD3_bse16[RUD3_bse16['Data']=='Train'], RUD3_bse16[RUD3_bse16['Data']=='Test']

# RUD5_bse16 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/16qubit/5RUD/A2_Hadamard/A2_Hadamard_predicted_values.csv'))
# RUD5_bse16['Predicted'] = [float(i.strip('[]')) for i in RUD5_bse16['Predicted']]
# RUD5_bse16['Reference']= [float(i.strip('[]')) for i in RUD5_bse16['Reference']]
# RUD5_bse16_train, RUD5_bse16_test = RUD5_bse16[RUD5_bse16['Data']=='Train'], RUD5_bse16[RUD5_bse16['Data']=='Test']

# # Define the datasets
# datasets = {
#     "AL=1, RUD=1": best_bse16,
#     "AL=3, RUD=1": AL3_bse16,
#     "AL=5, RUD=1": AL5_bse16,
#     "AL=1, RUD=3": RUD3_bse16,
#     "AL=1, RUD=5": RUD5_bse16
# }

# SIZE = 16

# plt.rc('font', size=SIZE)          # controls default text sizes
# plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
# plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
# plt.rc('legend', fontsize=SIZE)    # legend fontsize
# plt.rc('figure', titlesize=SIZE)  # fontsize of the figure title
# # Create the figure with a 2D grid (scatter + KDE for Predicted + KDE for Reference)
# fig, axes = plt.subplots(
#     2, 6, 
#     figsize=(30, 8), 
#     gridspec_kw={'width_ratios': [4, 4, 4, 4, 4, 2], 'height_ratios': [1, 4]}, 
#     sharey='row',  # Keep y-axis sharing, but remove sharex to control ticks manually,
#     sharex='col'
# )

# # Iterate through datasets and create scatter + KDE plots
# for i, (title, data) in enumerate(datasets.items()):
#     # KDE plot of "Predicted" (top row)
#     sns.kdeplot(data=data, x="Predicted", hue='Data', ax=axes[0, i], fill=True, palette=cmap,multiple='stack')
#     axes[0, i].set_xticklabels([])  # Hide labels but keep ticks
#     axes[0, i].set_xlabel("")  # Remove x-labels
#     axes[0, i].set_title(title)
#     axes[0, i].set_yticks(axes[0, i].get_yticks())  # Hide x-tick labels
#     axes[0, i].set_yticklabels(axes[0, i].get_yticks())  # Hide x-tick labels    
    
#     # Scatter plot in the middle row
#     sns.scatterplot(data=data, x="Predicted", y="Reference", hue="Data", ax=axes[1, i], alpha=0.7, edgecolor='k', palette=cmap)
#     axes[1, i].plot(range(-1,2),range(-1,2),'k--',alpha=0.5)
#     axes[1, i].set_ylabel(r'Reference BSE (kcal/mol)' if i == 0 else "")  # Show y-label only for first column
#     axes[1, i].tick_params(axis='x')  # Ensure x-tick labels are visible
#     axes[1, i].set_xlabel(r'Predicted BSE (kcal/mol)')
#     axes[1,i].set_ylim(0,200)
#     axes[1,i].set_xlim(0,200)
#     axes[1, i].set_xticks(np.linspace(0,200,5))  # Hide x-tick labels
#     axes[1, i].set_xticklabels([f'{i:.2f}' for i in np.linspace(0,200,5)])  # Hide x-tick labels    
#     axes[1, i].set_yticks(np.linspace(0,200,5))  # Hide x-tick labels
#     axes[1, i].set_yticklabels([f'{i:.2f}' for i in np.linspace(0,200,5)])  # Hide x-tick labels      
#     # axes[1, i].vlines(best_bse5['Reference'].mean(),-10,210,color='r',label=f"{best_bse16['Reference'].mean():.2f}")
# # KDE plot of "Reference" on the far-right column (across all datasets)
# sns.kdeplot(data=best_bse16, y="Reference", hue='Data', ax=axes[1, 5], fill=True, palette=cmap,multiple='stack')
# # axes[1, 5].set_xlabel("")  # Remove x-label
# axes[1, 5].set_xticks(axes[1, 5].get_xticks())  # Hide x-tick labels
# axes[1, 5].set_xticklabels(axes[1, 5].get_xticks())  # Hide x-tick labels

# # Remove empty top-right subplot
# axes[0, 5].axis("off")
# plt.suptitle('16 Qubit BSE49 A2_Hadamard')
# # Adjust layout
# plt.tight_layout()
# plt.savefig(os.path.join(os.path.expanduser('~'),'qregress/images/BSE/sixteenqubit/distribution_parity.png'),dpi=300,bbox_inches='tight')
# plt.show()

# %%
# best_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE-calc-test/5qubit/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
# best_bse5['Predicted'] = [float(i.strip('[]')) for i in best_bse5['Predicted']]
# best_bse5['Reference']= [float(i.strip('[]')) for i in best_bse5['Reference']]
# best_bse5_train, best_bse5_test = best_bse5[best_bse5['Data']=='Train'], best_bse5[best_bse5['Data']=='Test']

# AL3_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/3AL/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
# AL3_bse5['Predicted'] = [float(i.strip('[]')) for i in AL3_bse5['Predicted']]
# AL3_bse5['Reference']= [float(i.strip('[]')) for i in AL3_bse5['Reference']]
# AL3_bse5_train, AL3_bse5_test = AL3_bse5[AL3_bse5['Data']=='Train'], AL3_bse5[AL3_bse5['Data']=='Test']

# AL5_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/5AL/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
# AL5_bse5['Predicted'] = [float(i.strip('[]')) for i in AL5_bse5['Predicted']]
# AL5_bse5['Reference']= [float(i.strip('[]')) for i in AL5_bse5['Reference']]
# AL5_bse5_train, AL5_bse5_test = AL5_bse5[AL5_bse5['Data']=='Train'], AL5_bse5[AL5_bse5['Data']=='Test']

# RUD3_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/3RUD/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
# RUD3_bse5['Predicted'] = [float(i.strip('[]')) for i in RUD3_bse5['Predicted']]
# RUD3_bse5['Reference']= [float(i.strip('[]')) for i in RUD3_bse5['Reference']]
# RUD3_bse5_train, RUD3_bse5_test = RUD3_bse5[RUD3_bse5['Data']=='Train'], RUD3_bse5[RUD3_bse5['Data']=='Test']

# RUD5_bse5 = pd.read_csv(os.path.join(os.path.expanduser('~'),'qregress/BSE_RUD_AL_test/5qubit/5RUD/M-M-CZ_HWE-CNOT/M-M-CZ_HWE-CNOT_predicted_values.csv'))
# RUD5_bse5['Predicted'] = [float(i.strip('[]')) for i in RUD5_bse5['Predicted']]
# RUD5_bse5['Reference']= [float(i.strip('[]')) for i in RUD5_bse5['Reference']]
# RUD5_bse5_train, RUD5_bse5_test = RUD5_bse5[RUD5_bse5['Data']=='Train'], RUD5_bse5[RUD5_bse5['Data']=='Test']

# # Define the datasets
# datasets = {
#     "AL=1, RUD=1": best_bse5,
#     "AL=3, RUD=1": AL3_bse5,
#     "AL=5, RUD=1": AL5_bse5,
#     "AL=1, RUD=3": RUD3_bse5,
#     "AL=1, RUD=5": RUD5_bse5
# }

# SIZE = 16

# plt.rc('font', size=SIZE)          # controls default text sizes
# plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
# plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
# plt.rc('legend', fontsize=SIZE)    # legend fontsize
# plt.rc('figure', titlesize=SIZE)  # fontsize of the figure title
# # Create the figure with a 2D grid (scatter + KDE for Predicted + KDE for Reference)
# fig, axes = plt.subplots(
#     2, 6, figsize=(30, 8), 
#     gridspec_kw={'width_ratios': [4, 4, 4, 4, 4, 2], 'height_ratios': [1, 4]}, 
#     sharey='row',  # Keep y-axis sharing, but remove sharex to control ticks manually,
#     sharex='col'
# )

# # Iterate through datasets and create scatter + KDE plots
# for i, (title, data) in enumerate(datasets.items()):
#     # KDE plot of "Predicted" (top row)
#     sns.kdeplot(data=data, x="Predicted", hue='Data', ax=axes[0, i], fill=True, palette=cmap,multiple='stack')
#     axes[0, i].set_xticklabels([])  # Hide labels but keep ticks
#     axes[0, i].set_xlabel("")  # Remove x-labels
#     axes[0, i].set_title(title)
#     axes[0, i].set_yticks(axes[0, i].get_yticks())  # Hide x-tick labels
#     axes[0, i].set_yticklabels(axes[0, i].get_yticks())  # Hide x-tick labels    
    
#     # Scatter plot in the middle row
#     sns.scatterplot(data=data, x="Predicted", y="Reference", hue="Data", ax=axes[1, i], alpha=0.7, edgecolor='k', palette=cmap)
#     axes[1, i].plot(range(-1,2),range(-1,2),'k--',alpha=0.5)
#     axes[1, i].set_ylabel(r'Reference BSE (kcal/mol)' if i == 0 else "")  # Show y-label only for first column
#     axes[1, i].tick_params(axis='x')  # Ensure x-tick labels are visible
#     axes[1, i].set_xlabel(r'Predicted BSE (kcal/mol)')
#     axes[1,i].set_ylim(0,200)
#     axes[1,i].set_xlim(0,200)
#     axes[1, i].set_xticks(np.linspace(0,200,5))  # Hide x-tick labels
#     axes[1, i].set_xticklabels([f'{i:.2f}' for i in np.linspace(0,200,5)])  # Hide x-tick labels    
#     axes[1, i].set_yticks(np.linspace(0,200,5))  # Hide x-tick labels
#     axes[1, i].set_yticklabels([f'{i:.2f}' for i in np.linspace(0,200,5)])  # Hide x-tick labels         
#     # axes[1, i].vlines(best_bse5['Reference'].mean(),-10,210,color='r',label=f"{best_bse16['Reference'].mean():.2f}")
# # KDE plot of "Reference" on the far-right column (across all datasets)
# sns.kdeplot(data=best_bse5, y="Reference", hue='Data', ax=axes[1, 5], fill=True, palette=cmap,multiple='stack')
# # axes[1, 5].set_xlabel("")  # Remove x-label
# axes[1, 5].set_xticks(axes[1, 5].get_xticks())  # Hide x-tick labels
# axes[1, 5].set_xticklabels(axes[1, 5].get_xticks())  # Hide x-tick labels

# # Remove empty top-right subplot
# axes[0, 5].axis("off")
# plt.suptitle('5 Qubit BSE49 M-M-CZ_HWE-CNOT')
# # Adjust layout
# plt.tight_layout()

# plt.savefig(os.path.join(os.path.expanduser('~'),'qregress/images/BSE/fivequbit/distribution_parity.png'),dpi=300,bbox_inches='tight')
# plt.show()

# %%
def results_df(path):
    '''
    Take the top directory where the results are and return a nice Pandas dataframe

    parameters
    ----------
    path: str
        Path to the top directory `path/*/*results.json`

    returns
    -------
    df: pd.DataFrame
        Dataframe containing results
    '''
    results_dict = {}
    for i in glob(os.path.join(path,'*/*results.json')):
        with open(i,'r') as f:
            results = json.load(f)
        name = os.path.basename(i).replace('_results.json','')
        results['encoder']=name.split('_')[0]
        results['ansatz']=name.split('_')[1]
        results_dict[name]=results

    df = pd.DataFrame(results_dict).T
    
    return df

# %%
def plot_all(df,name,save_dir):
    fig, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6), gridspec_kw={'width_ratios': [1, 1]})
    SMALL_SIZE = 8
    MEDIUM_SIZE = 12
    BIGGER_SIZE = 12
    figsize = fig.get_size_inches()
    fig.set_size_inches(figsize * 1.2)
    plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title
    
    
    sns.boxplot(data=df,x='encoder',y='value',hue='variable',ax=ax1,palette=sns.color_palette('Paired',2))
    ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90) 
    ax1.set_ylim(np.floor(df['value'].min()),np.ceil(df['value'].max()))
    ax1.set_ylabel('R$^{2}$')
    ax1.set_xlabel('Encoder')
    ax1.legend(title='')
    
    sns.boxplot(data=df,x='ansatz',y='value',hue='variable',ax=ax2,palette=sns.color_palette('Paired',2))
    ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90) 
    ax2.set_ylim(np.floor(df['value'].min()),np.ceil(df['value'].max()))
    ax2.set_ylabel('R$^{2}$')
    ax2.set_xlabel('Ansatz')
    ax2.legend(title='')
    plt.tight_layout()
    # plt.savefig(os.path.join(os.path.expanduser('~'),save_dir,f'{name}_boxplots.png'),dpi=300,bbox_inches='tight')
    plt.show()
    
    fig, (ax1, ax2) = plt.subplots(1,2,figsize=(13,6),sharey=False)
    SMALL_SIZE = 8
    MEDIUM_SIZE = 12
    BIGGER_SIZE = 12
    
    plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title
    figsize = fig.get_size_inches()
    fig.set_size_inches(figsize * 1.5)
    ax1=sns.heatmap(df[df['variable']=='Train'][["encoder", "ansatz", "value"]].pivot(index='encoder', columns='ansatz', values='value').astype(float),annot_kws={"size": 12}, square=True, annot=True, linewidth=.5,fmt='.2f',ax=ax1,vmax=1,vmin=-1,cbar=True,center=0,cmap='rocket')
    ax1.set_title("Train")
    ax1.set_ylabel('Encoder')
    ax1.set_xlabel('Ansatz')
    ax1.set_aspect("equal")
    
    ax2=sns.heatmap(df[df['variable']=='Test'][["encoder", "ansatz", "value"]].pivot(index='encoder', columns='ansatz', values='value').astype(float), annot_kws={"size": 12}, square=True, annot=True, linewidth=.5,fmt='.2f',ax=ax2,vmax=1,vmin=-1,center=0,cmap='rocket')
    ax2.set_title("Test")
    ax2.set_ylabel('Encoder')
    ax2.set_xlabel('Ansatz')
    ax2.set_aspect("equal")
    
    ax1.collections[0].colorbar.set_label('R$^{2}$')
    ax2.collections[0].colorbar.set_label('R$^{2}$')

    plt.subplots_adjust(wspace=0.1,hspace=0)
    plt.tight_layout()  # Leave space for color bar
    # plt.savefig(os.path.join(os.path.expanduser('~'),save_dir,f'{name}_heatplots.png'),dpi=300,bbox_inches='tight')
    plt.show()

# %%
def plot(data_dir,name,save_dir):
    df = results_df(data_dir).rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])
    plot_all(df,name,save_dir)

# %%
# plot("function-calc-test/fivequbit_tests/lin5qubit/",'linear','qregress/images/Function_Fitting/fivequbit/')
# plot("function-calc-test/fivequbit_tests/quad5qubit/",'quadratic','qregress/images/Function_Fitting/fivequbit/')
# plot("function-calc-test/fivequbit_tests/sin5qubit/",'sine','qregress/images/Function_Fitting/fivequbit/')

# %%
# plot("function-calc-test/sixteenqubit_test/lin16qubit/",'linear','qregress/images/Function_Fitting/sixteenqubit/')
# plot("function-calc-test/sixteenqubit_test/quad16qubit/",'quadratic','qregress/images/Function_Fitting/sixteenqubit/')
# plot("function-calc-test/sixteenqubit_test/sin16qubit/",'sine','qregress/images/Function_Fitting/sixteenqubit/')

# %%
plot("BSE-calc-test/5qubit/",'BSE','qregress/images/BSE/5qubit/')
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/4017884214.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/4017884214.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %%
plot("BSE-calc-test/16qubit/",'BSE','qregress/images/BSE/sixteenqubit/')
plot("qml_DDCC/5/",'DDCC','qregress/images/DDCC/')
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/4017884214.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/4017884214.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/4017884214.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/4017884214.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %%
checkbse5 = results_df("BSE-calc-test/5qubit/").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])
bse5df = results_df("BSE-calc-test/5qubit/").sort_values(by=['R2_train','R2_test'])

# %%
bse5df
# Out:
#                                       MSE_train  R2_train  MAE_train  \
# A1-A1-CZ_ESU2               [1851.026040554107] -1.467274  36.438565
# M-M-CZ_Modified-Pauli-CRZ   [1647.394254169743] -1.195849  34.809756
# M-M-CZ_Full-CRZ            [1647.3218608764612] -1.195752  34.813371
# M-M-CZ_Efficient-CRX       [1647.3176212068606] -1.195746  34.813744
# M-M-CZ_Efficient-CRZ       [1647.3042333300548] -1.195729  34.815387
# ...                                         ...       ...        ...
# M-A2-CNOT_Full-CRX          [633.2350892785679]  0.155947  18.686565
# M-M-CZ_HWE-CNOT             [632.9750202266637]  0.156293  18.984733
# M-A1-CNOT_Full-CRX          [614.9948135339756]   0.18026  18.692215
# A1-A1-CNOT_Full-CRX         [609.9431620769701]  0.186993  18.704942
# A1-A1-CZ_Full-CRX            [609.077230410332]  0.188147  18.816815
#
#                               MSE_test   R2_test   MAE_test     encoder  \
# A1-A1-CZ_ESU2              1915.607383 -1.477415  37.410919    A1-A1-CZ
# M-M-CZ_Modified-Pauli-CRZ  1748.910441  -1.26183  36.240502      M-M-CZ
# M-M-CZ_Full-CRZ            1748.704547 -1.261563   36.24252      M-M-CZ
# M-M-CZ_Efficient-CRX       1748.687785 -1.261542  36.242702      M-M-CZ
# M-M-CZ_Efficient-CRZ       1748.619885 -1.261454  36.243581      M-M-CZ
# ...                                ...       ...        ...         ...
# M-A2-CNOT_Full-CRX          644.444726  0.166553  19.002379   M-A2-CNOT
# M-M-CZ_HWE-CNOT             638.935971  0.173677  18.999803      M-M-CZ
# M-A1-CNOT_Full-CRX          623.769811  0.193291  18.888206   M-A1-CNOT
# A1-A1-CNOT_Full-CRX         615.431502  0.204075  18.750286  A1-A1-CNOT
# A1-A1-CZ_Full-CRX           601.465955  0.222137  18.599383    A1-A1-CZ
#
#                                        ansatz
# A1-A1-CZ_ESU2                            ESU2
# M-M-CZ_Modified-Pauli-CRZ  Modified-Pauli-CRZ
# M-M-CZ_Full-CRZ                      Full-CRZ
# M-M-CZ_Efficient-CRX            Efficient-CRX
# M-M-CZ_Efficient-CRZ            Efficient-CRZ
# ...                                       ...
# M-A2-CNOT_Full-CRX                   Full-CRX
# M-M-CZ_HWE-CNOT                      HWE-CNOT
# M-A1-CNOT_Full-CRX                   Full-CRX
# A1-A1-CNOT_Full-CRX                  Full-CRX
# A1-A1-CZ_Full-CRX                    Full-CRX
#
# [168 rows x 8 columns]

# %%
for i in np.unique(bse5df['encoder']):
    print(i)
    print(bse5df[bse5df['encoder']==i][['R2_train','R2_test','MAE_train','MAE_test']].astype(float).describe())
# Out:
# A1
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.057894  -0.051951  20.775086  21.262425
# std     0.270865   0.246708   3.069163   2.887820
# min    -0.906332  -0.819780  19.305309  19.628510
# 25%    -0.001015  -0.005995  19.959591  20.579271
# 50%    -0.000680  -0.004875  19.985704  20.597416
# 75%     0.000221  -0.004008  20.015212  20.635178
# max     0.119666   0.131542  30.484395  30.356392
# A1-A1-CNOT
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.028111  -0.024388  20.611898  21.129917
# std     0.096148   0.095505   1.372382   1.381447
# min    -0.202198  -0.174613  18.704942  18.750286
# 25%    -0.046785  -0.048045  19.966262  20.532986
# 50%    -0.008011  -0.005575  20.019235  20.591974
# 75%    -0.006403  -0.003428  21.145663  21.478827
# max     0.186993   0.204075  23.529575  23.756816
# A1-A1-CZ
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.103218  -0.099246  21.298517  21.782655
# std     0.433432   0.439663   4.782205   4.963661
# min    -1.467274  -1.477415  18.816815  18.599383
# 25%    -0.005562  -0.006769  20.002575  20.602630
# 50%    -0.002840  -0.005149  20.057208  20.652696
# 75%     0.000828  -0.001963  20.130899  20.684204
# max     0.188147   0.222137  36.438565  37.410919
# A2
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.188714  -0.173635  22.807222  23.226602
# std     0.167147   0.153203   2.171965   2.075435
# min    -0.617535  -0.551979  19.735719  20.155389
# 25%    -0.214522  -0.213328  21.844084  22.052978
# 50%    -0.213103  -0.201216  23.334652  23.881333
# 75%    -0.116737  -0.095149  23.497366  23.980426
# max     0.021320   0.037387  27.743799  27.578784
# A2-A2-CNOT
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.026869  -0.017291  20.481653  20.925597
# std     0.072425   0.073674   0.875608   0.907679
# min    -0.153098  -0.118057  19.356759  19.362951
# 25%    -0.069130  -0.052968  20.024269  20.616472
# 50%    -0.021671  -0.021567  20.114697  20.731701
# 75%    -0.019266  -0.016829  20.989147  21.432887
# max     0.105787   0.131574  22.378958  22.503641
# A2-A2-CZ
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.510282  -0.506046  26.745333  27.302352
# std     0.439986   0.470617   5.458104   5.903767
# min    -1.026566  -1.077645  19.081423  19.104175
# 25%    -1.026534  -1.077587  23.331413  23.401930
# 50%    -0.454023  -0.402225  26.091907  26.469034
# 75%    -0.237861  -0.203842  33.148923  34.377800
# max     0.142979   0.156689  33.154206  34.381271
# IQP
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.056498  -0.047766  20.875621  21.296848
# std     0.185895   0.176099   2.314256   2.235025
# min    -0.634958  -0.596126  19.962045  20.267255
# 25%    -0.016515  -0.011098  20.065870  20.626401
# 50%    -0.010612  -0.004947  20.189652  20.643577
# 75%    -0.004543  -0.003975  20.292705  20.774270
# max     0.104654   0.108692  28.187627  28.376115
# M
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.342047  -0.309429  24.213773  24.505721
# std     0.391224   0.359583   4.495055   4.248568
# min    -0.852339  -0.778956  19.292819  19.663683
# 25%    -0.852320  -0.778664  20.999148  21.594634
# 50%    -0.157899  -0.133507  21.983779  22.374098
# 75%    -0.044188  -0.050506  30.035592  29.994323
# max     0.064646   0.079328  30.037898  30.001205
# M-A1-CNOT
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.041332  -0.031203  20.712280  21.141780
# std     0.078888   0.075175   0.796394   0.792592
# min    -0.122171  -0.091633  18.692215  18.888206
# 25%    -0.082115  -0.069317  20.522168  21.072980
# 50%    -0.050970  -0.046768  20.842558  21.321410
# 75%    -0.042588  -0.037751  20.970553  21.412546
# max     0.180260   0.193291  21.692179  22.004956
# M-A1-CZ
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.373311  -0.363565  24.828086  25.324012
# std     0.465539   0.455165   5.640664   5.685518
# min    -0.945131  -0.915736  18.718553  18.919965
# 25%    -0.945013  -0.915298  19.944571  20.388873
# 50%    -0.218819  -0.186909  22.300113  22.635440
# 75%     0.029920   0.036136  31.618696  32.073903
# max     0.139903   0.144889  31.638688  32.098280
# M-A2-CNOT
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.036508  -0.033002  20.659672  21.188455
# std     0.069129   0.068582   0.821150   0.826934
# min    -0.113876  -0.098210  18.686565  19.002379
# 25%    -0.060145  -0.057027  20.414550  20.956392
# 50%    -0.058463  -0.051873  20.792582  21.297088
# 75%    -0.021683  -0.034858  20.848057  21.420097
# max     0.155947   0.166553  21.962821  22.354759
# M-A2-CZ
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.340668  -0.304146  24.253352  24.466983
# std     0.310404   0.312451   3.632216   3.733073
# min    -1.047218  -1.117329  19.644610  20.020497
# 25%    -0.477083  -0.394923  21.587175  22.312774
# 50%    -0.443611  -0.364074  25.093128  24.932515
# 75%    -0.079607  -0.080292  25.554154  25.222841
# max     0.091015   0.088631  33.197439  34.593695
# M-M-CNOT
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.016443  -0.014334  20.244133  20.779285
# std     0.043465   0.040261   0.739680   0.691390
# min    -0.092412  -0.072474  19.481524  19.951175
# 25%    -0.040319  -0.040280  19.776051  20.394439
# 50%    -0.003655  -0.004942  19.789632  20.425908
# 75%    -0.000751  -0.002626  20.766705  21.399637
# max     0.069820   0.080530  21.604123  21.925597
# M-M-CZ
#         R2_train    R2_test  MAE_train   MAE_test
# count  12.000000  12.000000  12.000000  12.000000
# mean   -0.477004  -0.484526  26.127718  26.759150
# std     0.558761   0.595406   6.648408   7.207667
# min    -1.195849  -1.261830  18.984733  18.999803
# 25%    -1.195733  -1.261476  21.317629  21.656973
# 50%    -0.276312  -0.227881  22.989023  23.085792
# 75%    -0.075403  -0.083527  34.810660  36.241006
# max     0.156293   0.173677  34.815387  36.243581

# %%
# Out:
# array(['A1', 'A1-A1-CNOT', 'A1-A1-CZ', 'A2', 'A2-A2-CNOT', 'A2-A2-CZ',
#        'IQP', 'M', 'M-A1-CNOT', 'M-A1-CZ', 'M-A2-CNOT', 'M-A2-CZ',
#        'M-M-CNOT', 'M-M-CZ'], dtype=object)

# %%
# Out:
#                                       MSE_train  R2_train  MAE_train  \
# A1-A1-CZ_ESU2               [1851.026040554107] -1.467274  36.438565
# M-M-CZ_Modified-Pauli-CRZ   [1647.394254169743] -1.195849  34.809756
# M-M-CZ_Full-CRZ            [1647.3218608764612] -1.195752  34.813371
# M-M-CZ_Efficient-CRX       [1647.3176212068606] -1.195746  34.813744
# M-M-CZ_Efficient-CRZ       [1647.3042333300548] -1.195729  34.815387
# ...                                         ...       ...        ...
# M-A2-CNOT_Full-CRX          [633.2350892785679]  0.155947  18.686565
# M-M-CZ_HWE-CNOT             [632.9750202266637]  0.156293  18.984733
# M-A1-CNOT_Full-CRX          [614.9948135339756]   0.18026  18.692215
# A1-A1-CNOT_Full-CRX         [609.9431620769701]  0.186993  18.704942
# A1-A1-CZ_Full-CRX            [609.077230410332]  0.188147  18.816815
#
#                               MSE_test   R2_test   MAE_test     encoder  \
# A1-A1-CZ_ESU2              1915.607383 -1.477415  37.410919    A1-A1-CZ
# M-M-CZ_Modified-Pauli-CRZ  1748.910441  -1.26183  36.240502      M-M-CZ
# M-M-CZ_Full-CRZ            1748.704547 -1.261563   36.24252      M-M-CZ
# M-M-CZ_Efficient-CRX       1748.687785 -1.261542  36.242702      M-M-CZ
# M-M-CZ_Efficient-CRZ       1748.619885 -1.261454  36.243581      M-M-CZ
# ...                                ...       ...        ...         ...
# M-A2-CNOT_Full-CRX          644.444726  0.166553  19.002379   M-A2-CNOT
# M-M-CZ_HWE-CNOT             638.935971  0.173677  18.999803      M-M-CZ
# M-A1-CNOT_Full-CRX          623.769811  0.193291  18.888206   M-A1-CNOT
# A1-A1-CNOT_Full-CRX         615.431502  0.204075  18.750286  A1-A1-CNOT
# A1-A1-CZ_Full-CRX           601.465955  0.222137  18.599383    A1-A1-CZ
#
#                                        ansatz
# A1-A1-CZ_ESU2                            ESU2
# M-M-CZ_Modified-Pauli-CRZ  Modified-Pauli-CRZ
# M-M-CZ_Full-CRZ                      Full-CRZ
# M-M-CZ_Efficient-CRX            Efficient-CRX
# M-M-CZ_Efficient-CRZ            Efficient-CRZ
# ...                                       ...
# M-A2-CNOT_Full-CRX                   Full-CRX
# M-M-CZ_HWE-CNOT                      HWE-CNOT
# M-A1-CNOT_Full-CRX                   Full-CRX
# A1-A1-CNOT_Full-CRX                  Full-CRX
# A1-A1-CZ_Full-CRX                    Full-CRX
#
# [168 rows x 8 columns]

# %%
checkbse5[checkbse5['encoder']=='A1-A1-CZ']['value'].astype(float).describe()
# Out:
# count    24.000000
# mean     -0.101232
# std       0.426967
# min      -1.477415
# 25%      -0.006274
# 50%      -0.003058
# 75%      -0.000600
# max       0.222137
# Name: value, dtype: float64

# %%
# [(i,checkbse5[checkbse5['encoder']==i]['value'].astype(float)) for i in set(checkbse5['encoder'])]
pd.concat([checkbse5[checkbse5['encoder']==i]['value'].astype(float).to_frame().describe().rename(columns={'value':i}) for i in set(checkbse5['encoder'])],axis=1).T.sort_values(by=['mean'])
# Out:
#             count      mean       std       min       25%       50%       75%  \
# A2-A2-CZ     24.0 -0.508164  0.445551 -1.077645 -1.026534 -0.427642 -0.207221
# M-M-CZ       24.0 -0.480765  0.564696 -1.261830 -1.195748 -0.252514 -0.083161
# M-A1-CZ      24.0 -0.368438  0.450289 -0.945131 -0.915399 -0.205255  0.036136
# M            24.0 -0.325738  0.367855 -0.852339 -0.778766 -0.141417 -0.046742
# M-A2-CZ      24.0 -0.322407  0.305154 -1.117329 -0.455392 -0.381408 -0.079607
# A2           24.0 -0.181174  0.156992 -0.617535 -0.213328 -0.212257 -0.095149
# A1-A1-CZ     24.0 -0.101232  0.426967 -1.477415 -0.006274 -0.003058 -0.000600
# A1           24.0 -0.054922  0.253392 -0.906332 -0.005523 -0.002634 -0.000263
# IQP          24.0 -0.052132  0.177140 -0.634958 -0.012141 -0.008814 -0.003975
# M-A1-CNOT    24.0 -0.036268  0.075538 -0.122171 -0.078291 -0.050949 -0.038168
# M-A2-CNOT    24.0 -0.034755  0.067366 -0.113876 -0.060145 -0.052035 -0.028577
# A1-A1-CNOT   24.0 -0.026249  0.093740 -0.202198 -0.048045 -0.007997 -0.004354
# A2-A2-CNOT   24.0 -0.022080  0.071613 -0.153098 -0.069130 -0.021671 -0.017006
# M-M-CNOT     24.0 -0.015389  0.040987 -0.092412 -0.040319 -0.004723 -0.002054
#
#                  max
# A2-A2-CZ    0.156689
# M-M-CZ      0.173677
# M-A1-CZ     0.144889
# M           0.079328
# M-A2-CZ     0.091015
# A2          0.037387
# A1-A1-CZ    0.222137
# A1          0.131542
# IQP         0.108692
# M-A1-CNOT   0.193291
# M-A2-CNOT   0.166553
# A1-A1-CNOT  0.204075
# A2-A2-CNOT  0.131574
# M-M-CNOT    0.080530

# %%
pd.concat([checkbse5[checkbse5['ansatz']==i]['value'].astype(float).to_frame().describe().rename(columns={'value':i}) for i in set(checkbse5['ansatz'])],axis=1).T.sort_values(by=['mean'])
# Out:
#                     count      mean       std       min       25%       50%  \
# ESU2                 28.0 -0.454812  0.435693 -1.477415 -0.622825 -0.367010
# Efficient-CRX        28.0 -0.344598  0.449807 -1.261542 -0.797276 -0.051426
# Full-CRZ             28.0 -0.344576  0.449855 -1.261563 -0.797300 -0.051406
# Modified-Pauli-CRZ   28.0 -0.344513  0.449859 -1.261830 -0.797114 -0.051568
# Efficient-CRZ        28.0 -0.344496  0.449806 -1.261454 -0.797070 -0.051731
# Modified-Pauli-CRX   28.0 -0.116033  0.142601 -0.457209 -0.174371 -0.074689
# Hadamard             28.0 -0.114909  0.157702 -0.634958 -0.129903 -0.082215
# Full-Pauli-CRX       28.0 -0.109804  0.125289 -0.450838 -0.205634 -0.043874
# HWE-CZ               28.0 -0.085220  0.129385 -0.448166 -0.114182 -0.062588
# Full-Pauli-CRZ       28.0 -0.072357  0.123889 -0.401690 -0.095017 -0.024894
# HWE-CNOT             28.0  0.041575  0.063596 -0.050363 -0.001948  0.021487
# Full-CRX             28.0  0.121416  0.060256 -0.020318  0.090419  0.128929
#
#                          75%       max
# ESU2               -0.080188 -0.002176
# Efficient-CRX      -0.006355 -0.000809
# Full-CRZ           -0.005560 -0.000691
# Modified-Pauli-CRZ -0.005376 -0.000680
# Efficient-CRZ      -0.006027 -0.000680
# Modified-Pauli-CRX -0.005282  0.018323
# Hadamard           -0.014274  0.015571
# Full-Pauli-CRX     -0.020645  0.007746
# HWE-CZ             -0.002443  0.113484
# Full-Pauli-CRZ     -0.010053  0.106874
# HWE-CNOT            0.084354  0.173677
# Full-CRX            0.159155  0.222137

# %%
sorted([(i,f"{checkbse5[checkbse5['encoder']==i]['value'].astype(float).mean():.4f}") for i in set(checkbse5['encoder'])],key=lambda x: x[1])
# Out:
# [('M-M-CNOT', '-0.0154'),
#  ('A2-A2-CNOT', '-0.0221'),
#  ('A1-A1-CNOT', '-0.0262'),
#  ('M-A2-CNOT', '-0.0348'),
#  ('M-A1-CNOT', '-0.0363'),
#  ('IQP', '-0.0521'),
#  ('A1', '-0.0549'),
#  ('A1-A1-CZ', '-0.1012'),
#  ('A2', '-0.1812'),
#  ('M-A2-CZ', '-0.3224'),
#  ('M', '-0.3257'),
#  ('M-A1-CZ', '-0.3684'),
#  ('M-M-CZ', '-0.4808'),
#  ('A2-A2-CZ', '-0.5082')]

# %%
sorted([(i,f"{checkbse5[checkbse5['ansatz']==i]['value'].astype(float).mean():.4f}") for i in set(checkbse5['ansatz'])],key=lambda x: x[1])
# Out:
# [('Full-Pauli-CRZ', '-0.0724'),
#  ('HWE-CZ', '-0.0852'),
#  ('Full-Pauli-CRX', '-0.1098'),
#  ('Hadamard', '-0.1149'),
#  ('Modified-Pauli-CRX', '-0.1160'),
#  ('Efficient-CRZ', '-0.3445'),
#  ('Modified-Pauli-CRZ', '-0.3445'),
#  ('Efficient-CRX', '-0.3446'),
#  ('Full-CRZ', '-0.3446'),
#  ('ESU2', '-0.4548'),
#  ('HWE-CNOT', '0.0416'),
#  ('Full-CRX', '0.1214')]

# %%
def plot_combined(df,name,save_dir):


    fig, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6), gridspec_kw={'width_ratios': [1, 1]})
    SMALL_SIZE = 8
    MEDIUM_SIZE = 12
    BIGGER_SIZE = 12
    figsize = fig.get_size_inches()
    fig.set_size_inches(figsize * 1.2)
    plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title
    
    
    sns.boxplot(data=df,x='encoder',y='value',hue='variable',ax=ax1,palette=sns.color_palette('Paired',2))
    ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90) 
    ax1.set_ylim(np.floor(df['value'].min()),np.ceil(df['value'].max()))
    ax1.set_ylabel('R$^{2}$')
    ax1.set_xlabel('Encoder')
    ax1.legend(title='')
    
    sns.boxplot(data=df,x='ansatz',y='value',hue='variable',ax=ax2,palette=sns.color_palette('Paired',2))
    ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90) 
    ax2.set_ylim(np.floor(df['value'].min()),np.ceil(df['value'].max()))
    ax2.set_ylabel('R$^{2}$')
    ax2.set_xlabel('Ansatz')
    ax2.legend(title='')
    plt.tight_layout()
    # plt.savefig(os.path.join(os.path.expanduser('~'),save_dir,f'{name}_boxplots.png'),dpi=300,bbox_inches='tight')
    plt.show()

# %%
concatfive = pd.concat([results_df("function-calc-test/fivequbit_tests/lin5qubit/"),results_df("function-calc-test/fivequbit_tests/quad5qubit/"),results_df("function-calc-test/fivequbit_tests/sin5qubit/")]).rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])

# %%
lin5 = results_df("function-calc-test/fivequbit_tests/lin5qubit/").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])
quad5 = results_df("function-calc-test/fivequbit_tests/quad5qubit/").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])
sin5 = results_df("function-calc-test/fivequbit_tests/sin5qubit/").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])

# %%
check5 = results_df("function-calc-test/fivequbit_tests/lin5qubit//")
check5[(check5['R2_train']>=0.988)&(check5['R2_test']>=0.988)].sort_values(by=['R2_test','R2_train'])
# Out:
#                              MSE_train  R2_train MAE_train  MSE_test  \
# A1_Full-Pauli-CRZ  [2.397862805012619]  0.988383  1.154426  1.819878
# A1_ESU2            [2.353543051931622]  0.988598  1.140784  1.772258
#
#                     R2_test  MAE_test encoder          ansatz
# A1_Full-Pauli-CRZ   0.98903  1.166496      A1  Full-Pauli-CRZ
# A1_ESU2            0.989317  1.165076      A1            ESU2

# %%
sorted([(i,f"{concatfive[concatfive['encoder']==i]['value'].astype(float).mean():.4f}") for i in set(concatfive['encoder'])],key=lambda x: x[1])
# Out:
# [('M-M-CNOT', '0.0858'),
#  ('A2-A2-CZ', '0.1480'),
#  ('M-M-CZ', '0.1816'),
#  ('M-A1-CNOT', '0.1895'),
#  ('M-A2-CNOT', '0.1991'),
#  ('A2-A2-CNOT', '0.2227'),
#  ('A1-A1-CNOT', '0.2659'),
#  ('A1', '0.3454'),
#  ('M', '0.3904'),
#  ('A1-A1-CZ', '0.3909'),
#  ('M-A1-CZ', '0.4539'),
#  ('A2', '0.4563'),
#  ('IQP', '0.4658'),
#  ('M-A2-CZ', '0.4776')]

# %%
sorted([(i,f"{concatfive[concatfive['ansatz']==i]['value'].astype(float).mean():.4f}") for i in set(concatfive['ansatz'])],key=lambda x: x[1])
# Out:
# [('ESU2', '0.1059'),
#  ('Efficient-CRZ', '0.1127'),
#  ('Efficient-CRX', '0.1178'),
#  ('Modified-Pauli-CRZ', '0.1281'),
#  ('Full-CRZ', '0.1402'),
#  ('Hadamard', '0.1545'),
#  ('HWE-CZ', '0.4113'),
#  ('Full-Pauli-CRZ', '0.4197'),
#  ('Modified-Pauli-CRX', '0.4306'),
#  ('Full-Pauli-CRX', '0.4579'),
#  ('HWE-CNOT', '0.4815'),
#  ('Full-CRX', '0.7023')]

# %%
plot_combined(concatfive,'five_feature_function_fitting','qregress/images/Function_Fitting/fivequbit/')
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/753697863.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/753697863.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %%
concatsixteen = pd.concat([results_df("function-calc-test/sixteenqubit_test/lin16qubit/"),results_df("function-calc-test/sixteenqubit_test/quad16qubit//"),results_df("function-calc-test/sixteenqubit_test/sin16qubit/")]).rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])

# %%
lin16 = results_df("function-calc-test/sixteenqubit_test/lin16qubit/").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])
quad16 = results_df("function-calc-test/sixteenqubit_test/quad16qubit//").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])
sin16 = results_df("function-calc-test/sixteenqubit_test/sin16qubit/").rename(columns={'R2_train':'Train','R2_test':'Test'}).melt(id_vars=['encoder','ansatz'], value_vars=['Train','Test']).sort_values(by=['encoder','ansatz'])

# %%
check = results_df("function-calc-test/sixteenqubit_test/lin16qubit//")
check[(check['R2_train']>=0.988)&(check['R2_test']>=0.988)].sort_values(by=['R2_test','R2_train'])
# Out:
#                                MSE_train  R2_train MAE_train  MSE_test  \
# IQP_Full-Pauli-CRZ  [2.4221746931865233]  0.988265  1.197941  1.804454
# A1_ESU2             [2.3534968304735986]  0.988598  1.141239  1.775223
#
#                      R2_test  MAE_test encoder          ansatz
# IQP_Full-Pauli-CRZ  0.989123  1.091792     IQP  Full-Pauli-CRZ
# A1_ESU2             0.989299  1.164055      A1            ESU2

# %%
sorted([(i,f"{sin16[sin16['encoder']==i]['value'].astype(float).mean():.4f}") for i in set(sin16['encoder'])],key=lambda x: x[1])
# Out:
# [('M-M-CNOT', '-0.0161'),
#  ('A2-A2-CZ', '-0.0216'),
#  ('A2-A2-CNOT', '-0.0318'),
#  ('A1-A1-CNOT', '-0.0556'),
#  ('M-A2-CNOT', '0.0592'),
#  ('M-A1-CNOT', '0.0642'),
#  ('M-M-CZ', '0.1292'),
#  ('A2', '0.2414'),
#  ('A1-A1-CZ', '0.2840'),
#  ('A1', '0.3090'),
#  ('IQP', '0.4684'),
#  ('M-A2-CZ', '0.4998'),
#  ('M-A1-CZ', '0.5125'),
#  ('M', '0.5570')]

# %%
sorted([(i,f"{sin16[sin16['ansatz']==i]['value'].astype(float).mean():.4f}") for i in set(sin16['ansatz'])],key=lambda x: x[1])
# Out:
# [('HWE-CNOT', '-0.0306'),
#  ('Efficient-CRZ', '0.0839'),
#  ('Efficient-CRX', '0.0839'),
#  ('Modified-Pauli-CRZ', '0.0839'),
#  ('Full-CRZ', '0.0839'),
#  ('Full-CRX', '0.1619'),
#  ('ESU2', '0.2452'),
#  ('Hadamard', '0.2592'),
#  ('Modified-Pauli-CRX', '0.3183'),
#  ('Full-Pauli-CRX', '0.3754'),
#  ('HWE-CZ', '0.4179'),
#  ('Full-Pauli-CRZ', '0.4881')]

# %%
plot_combined(concatsixteen,'sixteen_feature_function_fitting','qregress/images/Function_Fitting/sixteenqubit/')
# Out:
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/753697863.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /var/folders/px/qyhp9b8j4bb0z5wgydzgkpxw0000gn/T/ipykernel_8585/753697863.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %%
'images/Function_Fitting/sixteenqubit/sixteen_feature_function_fitting_boxplots.png'
# Out:
# 'images/Function_Fitting/sixteenqubit/sixteen_feature_function_fitting_boxplots.png'
