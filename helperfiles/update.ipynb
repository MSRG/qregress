# %%
import os, sys, shutil
from glob import glob
import pandas as pd
import json

# %%
for i in glob('*/*.json'):
    if 'results' not in i:
        print(i)
        name = os.path.dirname(i)
        logfile = os.path.join(name,'model_log.csv')
        if os.path.exists(logfile):
            df = pd.read_csv(logfile).dropna()
            itermax = df['Iteration'].iloc[-1]
            
            paramfile = os.path.join(name, f'{name}.json')
        
            # Load JSON config
            with open(paramfile, 'r') as f:
                paramdict = json.load(f)
        
            if int(itermax) != 999:
                print(f"Number ran = {int(itermax)}\nCurrent max: {paramdict['MAX_ITER']}")
                paramdict['MAX_ITER'] = 999 - int(itermax)
                print(f"New max: {paramdict['MAX_ITER']}")
        
                # Update JSON file
                with open(paramfile, 'w') as f:
                    json.dump(paramdict, f, indent=4)
        
            # Handle file renaming and enumeration
            existing_files = glob(os.path.join(name, '*_model_log.csv'))
            if existing_files:
                # Get the highest prefix number from existing files
                highest_num = max(
                    int(os.path.basename(f).split('_')[0]) 
                    for f in existing_files 
                    if os.path.basename(f).split('_')[0].isdigit()
                )
                new_filename = os.path.join(name, f"{highest_num + 1}_model_log.csv")
            else:
                # If no other files exist, move to 1_model_log.csv
                new_filename = os.path.join(name, "1_model_log.csv")
        
            shutil.move(logfile, new_filename)
            print(f"Moved {logfile} to {new_filename}")
        else:
            paramfile = os.path.join(name, f'{name}.json')
        
            # Load JSON config
            with open(paramfile, 'r') as f:
                paramdict = json.load(f)      
            
            paramdict['MAX_ITER'] = 1000
            print(f"New max: {paramdict['MAX_ITER']}\n")
            # Update JSON file
            with open(paramfile, 'w') as f:
                json.dump(paramdict, f, indent=4)        
    print()
# Out:
# A1_Efficient-CRX/A1_Efficient-CRX.json
# New max: 1000
#
#
#
# A1-A1-CZ_ESU2/A1-A1-CZ_ESU2.json
# New max: 1000
#
#
# M-A2-CNOT_ESU2/M-A2-CNOT_ESU2.json
# New max: 1000
#
#
# M-A1-CZ_ESU2/M-A1-CZ_ESU2.json
# New max: 1000
#
#
#
# M-A2-CZ_Efficient-CRX/M-A2-CZ_Efficient-CRX.json
# New max: 1000
#
#
#
# M-M-CZ_Efficient-CRZ/M-M-CZ_Efficient-CRZ.json
# New max: 1000
#
#
#
# A2-A2-CZ_Efficient-CRZ/A2-A2-CZ_Efficient-CRZ.json
# New max: 1000
#
#
#
#
# A1-A1-CNOT_Efficient-CRZ/A1-A1-CNOT_Efficient-CRZ.json
# New max: 1000
#
#
#
# IQP_Efficient-CRX/IQP_Efficient-CRX.json
# New max: 1000
#
#
# M-M-CNOT_ESU2/M-M-CNOT_ESU2.json
# New max: 1000
#
#
#
#
# A2_Efficient-CRX/A2_Efficient-CRX.json
# New max: 1000
#
#
# A2-A2-CNOT_Efficient-CRX/A2-A2-CNOT_Efficient-CRX.json
# New max: 1000
#
#
# M_Full-CRZ/M_Full-CRZ.json
# New max: 1000
#
#
#
# A1-A1-CZ_Efficient-CRX/A1-A1-CZ_Efficient-CRX.json
# New max: 1000
#
#
#
# M_ESU2/M_ESU2.json
# New max: 1000
#
#
#
#
# M-M-CNOT_Efficient-CRZ/M-M-CNOT_Efficient-CRZ.json
# New max: 1000
#
#
#
# A1-A1-CZ_Full-CRZ/A1-A1-CZ_Full-CRZ.json
# New max: 1000
#
#
# IQP_ESU2/IQP_ESU2.json
# New max: 1000
#
#
#
# M-A2-CNOT_Efficient-CRZ/M-A2-CNOT_Efficient-CRZ.json
# New max: 1000
#
#
#
# M-A2-CZ_HWE-CZ/M-A2-CZ_HWE-CZ.json
# New max: 1000
#
#
# M-A2-CZ_ESU2/M-A2-CZ_ESU2.json
# New max: 1000
#
#
# M-A1-CZ_Efficient-CRZ/M-A1-CZ_Efficient-CRZ.json
# New max: 1000
#
#
#
# M-A1-CNOT_Efficient-CRZ/M-A1-CNOT_Efficient-CRZ.json
# New max: 1000
#
#
#
# A2-A2-CZ_Full-CRZ/A2-A2-CZ_Full-CRZ.json
# New max: 1000
#
#
#
# A1_Full-CRZ/A1_Full-CRZ.json
# New max: 1000
#
#
# A2_ESU2/A2_ESU2.json
# New max: 1000
#
#
#
# M_Efficient-CRX/M_Efficient-CRX.json
# New max: 1000
#
#
# M-M-CNOT_HWE-CZ/M-M-CNOT_HWE-CZ.json
# New max: 1000
#
#
#
# A1-A1-CNOT_Full-CRZ/A1-A1-CNOT_Full-CRZ.json
# New max: 1000
#
#
#
#
# A2-A2-CZ_Efficient-CRX/A2-A2-CZ_Efficient-CRX.json
# New max: 1000
#
#
# M-M-CZ_Efficient-CRX/M-M-CZ_Efficient-CRX.json
# New max: 1000
#
#
# A2-A2-CNOT_ESU2/A2-A2-CNOT_ESU2.json
# New max: 1000
#
#
# A1-A1-CNOT_ESU2/A1-A1-CNOT_ESU2.json
# New max: 1000
#
#
# M-A2-CZ_Efficient-CRZ/M-A2-CZ_Efficient-CRZ.json
# New max: 1000
#
#
#
# M-A2-CZ_HWE-CNOT/M-A2-CZ_HWE-CNOT.json
# New max: 1000
#
#
#
# A1_Efficient-CRZ/A1_Efficient-CRZ.json
# New max: 1000
#
#
# A2-A2-CNOT_Full-CRZ/A2-A2-CNOT_Full-CRZ.json
# New max: 1000
#
#
# A1_ESU2/A1_ESU2.json
# New max: 1000
#
#
# M-M-CNOT_HWE-CNOT/M-M-CNOT_HWE-CNOT.json
# New max: 1000
#
#
#
# M-A1-CZ_Full-CRZ/M-A1-CZ_Full-CRZ.json
# New max: 1000
#
#
#
#
# A2-A2-CNOT_Efficient-CRZ/A2-A2-CNOT_Efficient-CRZ.json
# New max: 1000
#
#
# A2_Efficient-CRZ/A2_Efficient-CRZ.json
# New max: 1000
#
#
#
# IQP_Efficient-CRZ/IQP_Efficient-CRZ.json
# New max: 1000
#
#
#
# A2-A2-CZ_ESU2/A2-A2-CZ_ESU2.json
# New max: 1000
#
#
# A1-A1-CNOT_Efficient-CRX/A1-A1-CNOT_Efficient-CRX.json
# New max: 1000
#
#
# M-A1-CZ_Efficient-CRX/M-A1-CZ_Efficient-CRX.json
# New max: 1000
#
#
#
# M-A2-CNOT_Efficient-CRX/M-A2-CNOT_Efficient-CRX.json
# New max: 1000
#
#
# M-A1-CNOT_ESU2/M-A1-CNOT_ESU2.json
# New max: 1000
#
#
#
# M-M-CNOT_Efficient-CRX/M-M-CNOT_Efficient-CRX.json
# New max: 1000
#
#
#
# M-A1-CNOT_Full-CRZ/M-A1-CNOT_Full-CRZ.json
# New max: 1000
#
#
#
# M-M-CZ_ESU2/M-M-CZ_ESU2.json
# New max: 1000
#
#
#
# A1-A1-CZ_Efficient-CRZ/A1-A1-CZ_Efficient-CRZ.json
# New max: 1000
#
#
#
# A2_Full-CRZ/A2_Full-CRZ.json
# New max: 1000
#
#
#
# A2-A2-CZ_HWE-CZ/A2-A2-CZ_HWE-CZ.json
# New max: 1000
#
#
#
# M-A2-CZ_Full-CRZ/M-A2-CZ_Full-CRZ.json
# New max: 1000
#
#
#
# IQP_Full-CRZ/IQP_Full-CRZ.json
# New max: 1000
#
#
# M-M-CNOT_Full-CRZ/M-M-CNOT_Full-CRZ.json
# New max: 1000
#
#
#
# A2-A2-CNOT_HWE-CZ/A2-A2-CNOT_HWE-CZ.json
# New max: 1000
#
#
#
#
# M_Efficient-CRZ/M_Efficient-CRZ.json
# New max: 1000
#
#
# M-M-CZ_Full-CRZ/M-M-CZ_Full-CRZ.json
# New max: 1000
#
#
# M-A2-CNOT_Full-CRZ/M-A2-CNOT_Full-CRZ.json
# New max: 1000
#
#
#
# M-A1-CNOT_Efficient-CRX/M-A1-CNOT_Efficient-CRX.json
# New max: 1000
